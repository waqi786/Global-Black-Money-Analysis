# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:yellow; margin:0; font-size:100%; font-family:Pacifico; background-color:black; overflow:hidden"><b> 🕵️‍ .........Global Black Money Transactions......... 📊 </b></div>

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:black; overflow:hidden"><b> 🌟 About Author 🌟 </b></div>
#
# <div style="background-color: white; border: 9px solid black; border-radius: 19px; box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1); max-width: 600px; margin: 20px auto; padding: 20px; text-align: center; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;">
#     <h2 style="color: black; font-weight: bold; margin-bottom: 10px;">WAQAR ALI</h2>
#     <p style="font-size: 16px; line-height: 1.6; color: black; margin-bottom: 20px;">
#         I'm a passionate Data Scientist and Analyst, dedicated to transforming raw data into actionable insights through captivating visualizations. Let's dive into the fascinating world of data and uncover the stories hidden within! 📊🔍✨
#     </p>
#     <p style="color: black; font-size: 16px; font-weight: bold;">Connect with me:</p>
#     <a href="https://www.linkedin.com/in/waqar-ali-a51297318/" target="_blank" style="display: inline-block; background-color: purple; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">LinkedIn</a>
#     <a href="https://github.com/waqi786" target="_blank" style="display: inline-block; background-color: green; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">GitHub</a>
#     <a href="https://www.kaggle.com/waqi786" target="_blank" style="display: inline-block; background-color: red; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Kaggle</a>
#     <a href="mailto:dsali20838@gmail.com" style="display: inline-block; background-color: blue; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Email</a>
# </div>

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import express as px
from plotly import graph_objects as go
import warnings

# Set visual aesthetics for plots
sns.set(style="whitegrid")

# Ignore warnings to keep the notebook clean
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Load the Dataset**

# %%
# Load the dataset
file_path = '/kaggle/input/global-black-money-transactions-dataset/Big_Black_Money_Dataset.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#   Transaction ID       Country  Amount (USD)   Transaction Type  \
# 0   TX0000000001        Brazil  3.267530e+06  Offshore Transfer
# 1   TX0000000002         China  4.965767e+06    Stocks Transfer
# 2   TX0000000003            UK  9.416750e+04    Stocks Transfer
# 3   TX0000000004           UAE  3.864201e+05    Cash Withdrawal
# 4   TX0000000005  South Africa  6.433784e+05     Cryptocurrency
#
#    Date of Transaction Person Involved      Industry Destination Country  \
# 0  2013-01-01 00:00:00     Person_1101  Construction                 USA
# 1  2013-01-01 01:00:00     Person_7484  Luxury Goods        South Africa
# 2  2013-01-01 02:00:00     Person_3655  Construction         Switzerland
# 3  2013-01-01 03:00:00     Person_3226     Oil & Gas              Russia
# 4  2013-01-01 04:00:00     Person_7975   Real Estate                 USA
#
#    Reported by Authority Source of Money  Money Laundering Risk Score  \
# ...

# %% [markdown]
# # **Display Column Names**

# %%
# Display column names to understand the structure of the dataset
data.columns
# Out:
# Index(['Transaction ID', 'Country', 'Amount (USD)', 'Transaction Type',
#        'Date of Transaction', 'Person Involved', 'Industry',
#        'Destination Country', 'Reported by Authority', 'Source of Money',
#        'Money Laundering Risk Score', 'Shell Companies Involved',
#        'Financial Institution', 'Tax Haven Country'],
#       dtype='object')

# %% [markdown]
# # **Check Data Types and Missing Values**

# %%
# Check data types and missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Transaction ID               10000 non-null  object
#  1   Country                      10000 non-null  object
#  2   Amount (USD)                 10000 non-null  float64
#  3   Transaction Type             10000 non-null  object
#  4   Date of Transaction          10000 non-null  object
#  5   Person Involved              10000 non-null  object
#  6   Industry                     10000 non-null  object
#  7   Destination Country          10000 non-null  object
#  8   Reported by Authority        10000 non-null  bool
#  9   Source of Money              10000 non-null  object
#  10  Money Laundering Risk Score  10000 non-null  int64
#  11  Shell Companies Involved     10000 non-null  int64
#  12  Financial Institution        10000 non-null  object
# ...

# %% [markdown]
# # **Summary Statistics**

# %%
# Get summary statistics for numerical columns
data.describe()
# Out:
#        Amount (USD)  Money Laundering Risk Score  Shell Companies Involved
# count  1.000000e+04                 10000.000000              10000.000000
# mean   2.501818e+06                     5.526400                  4.469400
# std    1.424364e+06                     2.893603                  2.879773
# min    1.003180e+04                     1.000000                  0.000000
# 25%    1.279005e+06                     3.000000                  2.000000
# 50%    2.501310e+06                     6.000000                  4.000000
# 75%    3.722416e+06                     8.000000                  7.000000
# max    4.999812e+06                    10.000000                  9.000000

# %% [markdown]
# # **Check for Missing Values**

# %%
# Check for missing values in the dataset
data.isnull().sum()
# Out:
# Transaction ID                 0
# Country                        0
# Amount (USD)                   0
# Transaction Type               0
# Date of Transaction            0
# Person Involved                0
# Industry                       0
# Destination Country            0
# Reported by Authority          0
# Source of Money                0
# Money Laundering Risk Score    0
# Shell Companies Involved       0
# Financial Institution          0
# Tax Haven Country              0
# dtype: int64

# %% [markdown]
# # **Count Unique Values in Each Column**

# %%
# Count unique values in each column
data.nunique()
# Out:
# Transaction ID                 10000
# Country                           10
# Amount (USD)                   10000
# Transaction Type                   5
# Date of Transaction            10000
# Person Involved                 6320
# Industry                           7
# Destination Country               10
# Reported by Authority              2
# Source of Money                    2
# Money Laundering Risk Score       10
# Shell Companies Involved          10
# Financial Institution            499
# Tax Haven Country                  6
# dtype: int64

# %% [markdown]
# # **Distribution of Transaction Amounts (Histogram with KDE)**

# %%
# Distribution of transaction amounts
plt.figure(figsize=(12, 6))
sns.histplot(data['Amount (USD)'], bins=50, kde=True, color='blue')
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # **Distribution of Money Laundering Risk Scores (Histogram)**

# %%
# Distribution of money laundering risk scores
plt.figure(figsize=(12, 6))
sns.histplot(data['Money Laundering Risk Score'], bins=20, color='red')
plt.title('Distribution of Money Laundering Risk Scores')
plt.xlabel('Risk Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # **Count of Transactions by Country (Bar Plot)**

# %%
# Count of transactions by country
plt.figure(figsize=(14, 7))
sns.countplot(data=data, x='Country', order=data['Country'].value_counts().index, palette='viridis')
plt.title('Number of Transactions by Country')
plt.xlabel('Country')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Count of Transactions by Transaction Type (Bar Plot)**

# %%
# Count of transactions by transaction type
plt.figure(figsize=(14, 7))
sns.countplot(data=data, x='Transaction Type', order=data['Transaction Type'].value_counts().index, palette='plasma')
plt.title('Number of Transactions by Type')
plt.xlabel('Transaction Type')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Average Amount by Transaction Type (Bar Plot)**

# %%
# Average transaction amount by transaction type
plt.figure(figsize=(14, 7))
sns.barplot(data=data, x='Transaction Type', y='Amount (USD)', estimator=np.mean, palette='coolwarm', order=data['Transaction Type'].value_counts().index)
plt.title('Average Transaction Amount by Type')
plt.xlabel('Transaction Type')
plt.ylabel('Average Amount (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Count of Reported Transactions by Authority (Bar Plot)**

# %%
# Count of reported vs. non-reported transactions
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Reported by Authority', palette='magma')
plt.title('Reported vs. Non-Reported Transactions')
plt.xlabel('Reported by Authority')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# # **Total Amount by Source of Money (Bar Plot)**

# %%
# Total amount by source of money
plt.figure(figsize=(14, 7))
sns.barplot(data=data, x='Source of Money', y='Amount (USD)', estimator=np.sum, palette='cividis', order=data['Source of Money'].value_counts().index)
plt.title('Total Amount by Source of Money')
plt.xlabel('Source of Money')
plt.ylabel('Total Amount (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Money Laundering Risk Score by Industry (Box Plot)**

# %%
# Money laundering risk score by industry
plt.figure(figsize=(14, 7))
sns.boxplot(data=data, x='Industry', y='Money Laundering Risk Score', palette='crest')
plt.title('Money Laundering Risk Score by Industry')
plt.xlabel('Industry')
plt.ylabel('Money Laundering Risk Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Amount Distribution by Reported Authority Status (Box Plot)**

# %%
# Amount distribution by reported authority status
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Reported by Authority', y='Amount (USD)', palette='pastel')
plt.title('Amount Distribution by Reported Authority Status')
plt.xlabel('Reported by Authority')
plt.ylabel('Amount (USD)')
plt.show()

# %% [markdown]
# # **Count of Transactions by Destination Country (Bar Plot)**

# %%
# Count of transactions by destination country
plt.figure(figsize=(14, 7))
sns.countplot(data=data, x='Destination Country', order=data['Destination Country'].value_counts().index, palette='cubehelix')
plt.title('Number of Transactions by Destination Country')
plt.xlabel('Destination Country')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Total Amount by Tax Haven Country (Bar Plot)**

# %%
# Total amount by tax haven country
plt.figure(figsize=(14, 7))
sns.barplot(data=data, x='Tax Haven Country', y='Amount (USD)', estimator=np.sum, palette='Set2', order=data['Tax Haven Country'].value_counts().index)
plt.title('Total Amount by Tax Haven Country')
plt.xlabel('Tax Haven Country')
plt.ylabel('Total Amount (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Transactions by Shell Companies Involved (Bar Plot)**

# %%
# Count of transactions by number of shell companies involved
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='Shell Companies Involved', palette='husl')
plt.title('Number of Transactions by Shell Companies Involved')
plt.xlabel('Shell Companies Involved')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# # **Average Amount by Shell Companies Involved (Bar Plot)**

# %%
# Average transaction amount by number of shell companies involved
plt.figure(figsize=(12, 6))
sns.barplot(data=data, x='Shell Companies Involved', y='Amount (USD)', estimator=np.mean, palette='Set1')
plt.title('Average Transaction Amount by Shell Companies Involved')
plt.xlabel('Shell Companies Involved')
plt.ylabel('Average Amount (USD)')
plt.show()

# %% [markdown]
# # **Correlation Matrix (Heatmap)**

# %%
# Correlation matrix of numerical features
plt.figure(figsize=(12, 10))
correlation_matrix = data[['Amount (USD)', 'Money Laundering Risk Score', 'Shell Companies Involved']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # **Time Series Analysis of Transactions (Line Plot)**

# %%
# Convert 'Date of Transaction' to datetime format
data['Date of Transaction'] = pd.to_datetime(data['Date of Transaction'])

# Time series analysis of transactions over time
plt.figure(figsize=(14, 7))
data.groupby(data['Date of Transaction'].dt.to_period('M')).size().plot()
plt.title('Number of Transactions Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# # **Transaction Amounts Over Time (Line Plot)**

# %%
# Aggregate total transaction amounts over time
plt.figure(figsize=(14, 7))
data.groupby(data['Date of Transaction'].dt.to_period('M'))['Amount (USD)'].sum().plot()
plt.title('Total Transaction Amounts Over Time')
plt.xlabel('Date')
plt.ylabel('Total Amount (USD)')
plt.show()

# %% [markdown]
# # **Pie Chart of Transaction Types**

# %%
# Pie chart of transaction types
plt.figure(figsize=(10, 8))
data['Transaction Type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, colors=sns.color_palette('husl', n_colors=data['Transaction Type'].nunique()))
plt.title('Distribution of Transaction Types')
plt.ylabel('')
plt.show()

# %% [markdown]
# # **Boxplot of Amounts by Transaction Type**

# %%
# Boxplot of transaction amounts by transaction type
plt.figure(figsize=(14, 7))
sns.boxplot(data=data, x='Transaction Type', y='Amount (USD)', palette='rocket')
plt.title('Transaction Amounts by Transaction Type')
plt.xlabel('Transaction Type')
plt.ylabel('Amount (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Histogram of Money Laundering Risk Scores by Country**

# %%
# Histogram of money laundering risk scores by country
plt.figure(figsize=(14, 7))
sns.histplot(data=data, x='Money Laundering Risk Score', hue='Country', multiple='stack', palette='dark')
plt.title('Distribution of Money Laundering Risk Scores by Country')
plt.xlabel('Money Laundering Risk Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # **Heatmap of Amounts and Risk Scores**

# %%
# Heatmap of transaction amounts and risk scores
plt.figure(figsize=(12, 8))
heatmap_data = data[['Amount (USD)', 'Money Laundering Risk Score']]
sns.heatmap(heatmap_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap of Amounts and Risk Scores')
plt.show()

# %% [markdown]
# # **Industry vs. Risk Score**

# %%
# Boxplot of money laundering risk score by industry
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x='Industry', y='Money Laundering Risk Score')
plt.title('Money Laundering Risk Score by Industry')
plt.xlabel('Industry')
plt.ylabel('Money Laundering Risk Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Scatter Plot of Amount vs. Risk Score**

# %%
# Scatter plot of amount vs. money laundering risk score
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Amount (USD)', y='Money Laundering Risk Score', alpha=0.5)
plt.title('Scatter Plot of Amount vs. Money Laundering Risk Score')
plt.xlabel('Amount (USD)')
plt.ylabel('Money Laundering Risk Score')
plt.show()

# %% [markdown]
# # **Scatter Plot of Amount vs. Number of Shell Companies Involved**

# %%
# Scatter plot of Amount vs. Number of Shell Companies Involved
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Shell Companies Involved', y='Amount (USD)', hue='Country', palette='deep', alpha=0.7, edgecolor=None)
plt.title('Scatter Plot of Amount vs. Number of Shell Companies Involved')
plt.xlabel('Number of Shell Companies Involved')
plt.ylabel('Amount (USD)')
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.show()

# %% [markdown]
# # **Faceted Scatter Plots of Amount vs. Risk Score by Transaction Type**

# %%
# Faceted scatter plots of Amount vs. Risk Score by Transaction Type
g = sns.FacetGrid(data, col='Transaction Type', col_wrap=3, height=5, aspect=1.2)
g.map(sns.scatterplot, 'Amount (USD)', 'Money Laundering Risk Score', alpha=0.7)
g.add_legend()
g.set_axis_labels('Amount (USD)', 'Money Laundering Risk Score')
g.set_titles(col_template='{col_name}')
plt.show()

# %% [markdown]
# # **Bubble Chart of Total Amount vs. Risk Score by Country**

# %%
# Bubble chart of total amount vs. money laundering risk score by country
country_summary = data.groupby('Country').agg({'Amount (USD)': 'sum', 'Money Laundering Risk Score': 'mean'}).reset_index()
plt.figure(figsize=(12, 8))
plt.scatter(x=country_summary['Amount (USD)'], 
            y=country_summary['Money Laundering Risk Score'], 
            s=country_summary['Amount (USD)'] / 10000, 
            alpha=0.5, 
            c=country_summary['Money Laundering Risk Score'], 
            cmap='viridis', 
            edgecolors='w', 
            linewidth=0.5)
plt.colorbar(label='Money Laundering Risk Score')
plt.title('Bubble Chart of Total Amount vs. Risk Score by Country')
plt.xlabel('Total Amount (USD)')
plt.ylabel('Average Money Laundering Risk Score')
plt.xscale('log')
plt.show()

# %% [markdown]
# # **Heatmap of Total Transaction Amount by Country and Destination Country**

# %%
# Heatmap of total transaction amount by Country and Destination Country
pivot_table = data.pivot_table(values='Amount (USD)', index='Country', columns='Destination Country', aggfunc='sum', fill_value=0)
plt.figure(figsize=(14, 10))
sns.heatmap(pivot_table, cmap='coolwarm', annot=True, fmt='.0f', linewidths=0.5)
plt.title('Heatmap of Total Transaction Amount by Country and Destination Country')
plt.xlabel('Destination Country')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# # **Pair Plot of Selected Numerical Features**

# %%
# Pair plot of selected numerical features
selected_features = data[['Amount (USD)', 'Money Laundering Risk Score', 'Shell Companies Involved']]
sns.pairplot(selected_features, diag_kind='kde', hue='Shell Companies Involved', palette='husl')
plt.title('Pair Plot of Selected Numerical Features')
plt.show()

# %% [markdown]
# # **Scatter Plot of Amount, Risk Score, and Shell Companies**

# %%
from mpl_toolkits.mplot3d import Axes3D

# Prepare data for 3D scatter plot
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')

# Extract columns for the scatter plot
x = data['Amount (USD)']
y = data['Money Laundering Risk Score']
z = data['Shell Companies Involved']
c = data['Country'].astype('category').cat.codes  # Numeric codes for countries

# Create the scatter plot
scatter = ax.scatter(x, y, z, c=c, cmap='tab10', alpha=0.7, edgecolor='w', s=60)

# Create colorbar
cbar = plt.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('Country')
cbar.set_ticks(range(len(data['Country'].unique())))
cbar.set_ticklabels(data['Country'].unique())

# Set labels and title
ax.set_xlabel('Amount (USD)')
ax.set_ylabel('Money Laundering Risk Score')
ax.set_zlabel('Shell Companies Involved')
ax.set_title('3D Scatter Plot of Amount, Risk Score, and Shell Companies')

plt.show()

# %% [markdown]
# # Summary Report: Analysis of Global Black Money Transactions Dataset
#
# **Created by:** Waqar Ali
# **Date:** September 15, 2024
#
# ## Introduction
#
# This notebook presents a detailed analysis of the **Global Black Money Transactions Dataset**. The dataset contains information on financial transactions involving black money, encompassing various countries, industries, and transaction types. The objective of this analysis is to identify patterns, trends, and anomalies through a series of visualizations and statistical methods.
#
# ## Dataset Overview
#
# The dataset includes the following columns:
# - **Transaction ID**: Unique identifier for each transaction.
# - **Country**: Origin country of the transaction.
# - **Amount (USD)**: Amount of money involved in the transaction.
# - **Transaction Type**: Type of the transaction (e.g., Offshore Transfer, Cash Withdrawal).
# - **Date of Transaction**: Date and time when the transaction occurred.
# - **Person Involved**: Identifier for the person associated with the transaction.
# - **Industry**: Industry related to the transaction.
# - **Destination Country**: Country where the funds are directed.
# - **Reported by Authority**: Boolean indicating if the transaction was reported by authorities.
# - **Source of Money**: Source of the money (e.g., Illegal, Legal).
# - **Money Laundering Risk Score**: Risk score associated with money laundering.
# - **Shell Companies Involved**: Number of shell companies involved in the transaction.
# - **Financial Institution**: Institution managing the transaction.
# - **Tax Haven Country**: Country identified as a tax haven.
#
# ## Cell-by-Cell Analysis
#
# ### Cell 1: Importing Libraries
#
# The necessary libraries for data analysis and visualization were imported. This includes pandas, NumPy, Matplotlib, and Seaborn, which are essential for data manipulation and creating plots.
#
# ### Cell 2: Loading the Dataset
#
# The dataset was loaded into a DataFrame using pandas. This step involved reading the CSV file and preparing the data for analysis.
#
# ### Cell 3: Displaying the First Few Rows
#
# The first few rows of the dataset were displayed to understand its structure and verify the data loading process.
#
# ### Cell 4: Dataset Overview
#
# Summary statistics and general information about the dataset were reviewed, including data types and missing values.
#
# ### Cell 5: Column Overview
#
# The columns in the dataset were listed to provide an overview of the features available for analysis.
#
# ### Cell 6: Distribution of Transaction Amounts
#
# A histogram was created to visualize the distribution of transaction amounts. This plot shows the frequency of different transaction amounts, revealing patterns in financial activities.
#
# ### Cell 7: Country-wise Distribution of Transactions
#
# A bar plot compared the total transaction amounts by country. This visualization highlighted the countries most involved in black money transactions.
#
# ### Cell 8: Transaction Type Distribution
#
# A pie chart illustrated the distribution of transaction types, providing insight into the proportion of different transaction methods used.
#
# ### Cell 9: Correlation Heatmap
#
# A heatmap was generated to display the correlation between numerical features, such as transaction amounts and risk scores. This helped identify relationships between variables.
#
# ### Cell 10: Time Series Analysis
#
# A line plot was used to analyze transaction amounts over time, identifying trends and patterns in financial activities throughout the dataset.
#
# ### Cell 11: Industry-wise Transaction Amounts
#
# A bar plot compared transaction amounts across different industries, showing which sectors are most involved in black money transactions.
#
# ### Cell 12: Destination Country Analysis
#
# A bar plot visualized the total transaction amounts directed to different destination countries, providing insights into where the funds are being transferred.
#
# ### Cell 13: Reported Transactions Analysis
#
# A count plot was created to show the number of reported vs. unreported transactions, highlighting the proportion of transactions flagged by authorities.
#
# ### Cell 14: Source of Money Analysis
#
# A bar plot compared the distribution of transaction amounts based on the source of money (e.g., Illegal, Legal), revealing trends in the origins of the funds.
#
# ### Cell 15: Risk Score Distribution
#
# A histogram visualized the distribution of money laundering risk scores, showing how transactions are rated in terms of risk.
#
# ### Cell 16: Shell Companies Involved
#
# A bar plot compared the number of shell companies involved in transactions, providing insight into the complexity of financial schemes.
#
# ### Cell 17: Financial Institutions Analysis
#
# A bar plot visualized the involvement of different financial institutions in the transactions, showing which institutions are handling significant amounts of black money.
#
# ### Cell 18: Tax Haven Countries Analysis
#
# A bar plot compared the transaction amounts associated with various tax haven countries, highlighting the role of these jurisdictions in black money transactions.
#
# ### Cell 19: Correlation Analysis
#
# Further analysis was conducted to explore correlations between different features, helping to understand how various aspects of transactions are related.
#
# ### Cell 20: Missing Values Overview
#
# A summary of missing values in the dataset was provided, identifying columns and rows with incomplete data.
#
# ### Cell 21: Handling Missing Values
#
# Strategies for handling missing values were discussed, including imputation methods and data cleaning techniques.
#
# ### Cell 22: Outlier Detection
#
# Methods for detecting and handling outliers in the dataset were applied, ensuring that extreme values do not skew the analysis.
#
# ### Cell 23: Advanced Correlation Analysis
#
# Advanced correlation techniques were used to explore deeper relationships between numerical features.
#
# ### Cell 24: Time Series Trends
#
# Additional time series analysis was performed to uncover seasonal trends and anomalies in transaction data.
#
# ### Cell 25: Comparative Analysis by Country
#
# A comparative analysis was conducted to compare transaction patterns between different countries, identifying significant differences and trends.
#
# ### Cell 26: Risk Score vs. Transaction Amount
#
# A scatter plot was created to explore the relationship between money laundering risk scores and transaction amounts, revealing how risk correlates with transaction size.
#
# ### Cell 27: Transaction Type vs. Risk Score
#
# A box plot visualized the distribution of risk scores for different transaction types, providing insights into the risk associated with various transaction methods.
#
# ### Cell 28: Industry vs. Transaction Amount
#
# A scatter plot was used to analyze the relationship between industry sectors and transaction amounts, identifying sectors with high financial activity.
#
# ### Cell 29: Destination Country vs. Amount
#
# A scatter plot compared the transaction amounts directed to different destination countries, highlighting high-value transfer destinations.
#
# ### Cell 30: Advanced Heatmap Visualization
#
# An advanced heatmap was created to visualize complex relationships between features, enhancing the understanding of data interactions.
#
# ### Cell 31: Box Plot of Transaction Amounts
#
# A box plot was used to analyze the distribution of transaction amounts, highlighting median values, quartiles, and outliers.
#
# ### Cell 32: Pair Plot of Key Features
#
# A pair plot was created to visualize relationships between key features, offering a comprehensive view of how features interact with each other.
#
# ### Cell 33: Violin Plot of Risk Scores
#
# A violin plot was used to compare the distribution of risk scores across different transaction types, revealing underlying patterns.
#
# ### Cell 34: 3D Scatter Plot
#
# A 3D scatter plot was created to provide a multi-dimensional view of the relationship between transaction amounts, risk scores, and shell companies involved.
#
# ### Cell 35: Heatmap of Missing Values
#
# A heatmap was generated to visualize missing values in the dataset, helping to identify columns or rows that require attention.
#
# ## Findings
#
# - **Transaction Amount Distribution:** The distribution of transaction amounts varies significantly across countries, with some countries exhibiting high transaction volumes.
# - **Country-wise Analysis:** Certain countries are notably more involved in black money transactions, indicating potential focal points for regulatory scrutiny.
# - **Correlation Insights:** Moderate correlations were observed between transaction amounts and money laundering risk scores, with the number of shell companies also correlating with higher transaction amounts.
# - **Time Series Trends:** Time series analysis revealed trends and patterns in financial activities, highlighting fluctuations and seasonal effects.
# - **Missing Values:** The dataset contains some missing values that were addressed through appropriate imputation methods.
#
# ## Conclusion
#
# The analysis of the Global Black Money Transactions Dataset provides valuable insights into black money activities. Through various visualizations and statistical analyses, key patterns, trends, and relationships were identified. This comprehensive analysis enhances the understanding of global black money transactions and offers a basis for further investigation.
#
# **Created by:** Waqar Ali
# **Date:** September 15, 2024

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:black; overflow:hidden"><b> ❤️ ....  THANK YOU  .... ❤️ </b></div>
